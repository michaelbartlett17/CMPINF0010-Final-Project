# %% [markdown]
# # Traffic Count
# For the analysis of the best Pittsburgh neighborhood by most accessible transportation, one of the datasets we chose to analyze was the amount of traffic in an area. This was chosed under the assumption that less traffic in an area makes for quicker traffic time, and reliable public transit.

# %%
import pandas as pd
import geopandas

# %%
neighborhoods = geopandas.read_file('Neighborhoods_.shp')
neighborhoods
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0       1293         201        42        003    980600          1
# 1       1294          10        42        003    261200          1
# 2       1295          11        42        003    260900          1
# 3       1296           7        42        003    262000          1
# 4       1297           8        42        003    261500          1
# ..       ...         ...       ...        ...       ...        ...
# 85      1378         251        42        003    320400          3
# 86      1379         265        42        003    563000          4
# 87      1380         358        42        003    562500          1
# 88      1381         298        42        003    563100          3
# 89      1382          32        42        003    562600          1
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...  page_numbe  \
# 0   420039806001  Block Group 1   G5030          S  ...          15
# 1   420032612001  Block Group 1   G5030          S  ...          15
# 2   420032609001  Block Group 1   G5030          S  ...          15
# 3   420032620001  Block Group 1   G5030          S  ...          15
# 4   420032615001  Block Group 1   G5030          S  ...          15
# ..           ...            ...     ...        ...  ...         ...
# 85  420033204003  Block Group 3   G5030          S  ...          15
# 86  420035630004  Block Group 4   G5030          S  ...          15
# 87  420035625001  Block Group 1   G5030          S  ...          15
# 88  420035631003  Block Group 3   G5030          S  ...          15
# 89  420035626001  Block Group 1   G5030          S  ...          15
#
#                plannerass created_us  created_da  last_edite  last_edi_1  \
# 0   Stephanie Joy Everett  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 1   Stephanie Joy Everett  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 2   Stephanie Joy Everett  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 3   Stephanie Joy Everett  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 4   Stephanie Joy Everett  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# ..                    ...        ...         ...         ...         ...
# 85         Sophia Robison  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 86         Sophia Robison  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 87         Sophia Robison  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 88         Sophia Robison  pgh.admin  2020-08-14   pgh.admin  2020-08-14
# 89         Sophia Robison  pgh.admin  2020-08-14   pgh.admin  2020-08-14
#
#     temp    Shape__Are    Shape__Len  \
# 0   None  1.068796e+07  19600.573085
# 1   None  1.133208e+07  21174.473326
# 2   None  8.743618e+06  13811.917169
# 3   None  1.754935e+07  18197.745741
# 4   None  2.522420e+07  26390.549314
# ..   ...           ...           ...
# 85  None  2.338689e+07  31964.844864
# 86  None  3.683820e+06   9978.225999
# 87  None  6.425358e+06  25260.814467
# 88  None  1.027920e+07  16308.247349
# 89  None  5.579476e+06  18778.991513
#
#                                              geometry
# 0   POLYGON ((-80.02999 40.45909, -80.02989 40.458...
# 1   POLYGON ((-80.01078 40.49975, -80.01073 40.499...
# 2   POLYGON ((-80.00327 40.48271, -80.00325 40.482...
# 3   POLYGON ((-79.99761 40.47460, -79.99761 40.474...
# 4   POLYGON ((-80.01422 40.47745, -80.01435 40.477...
# ..                                                ...
# 85  POLYGON ((-79.99633 40.39458, -79.99630 40.394...
# 86  POLYGON ((-80.06919 40.46046, -80.06912 40.460...
# 87  POLYGON ((-80.05154 40.46364, -80.05140 40.463...
# 88  POLYGON ((-80.03431 40.43366, -80.03424 40.433...
# 89  POLYGON ((-80.02821 40.44427, -80.02821 40.444...
#
# [90 rows x 39 columns]

# %%
traffic_data = pd.read_csv('traffic_data.csv')
traffic_data = traffic_data[~traffic_data.average_daily_car_traffic.isnull()]
traffic_data
# Out:
#              id  device_id    record_oid count_start_date count_end_date  \
# 0    1011743669         85  1.445865e+09       2019-04-18     2019-04-26
# 3     103627606          9  7.341951e+08       2018-07-17     2018-08-01
# 5    1041392556         76  5.713472e+08       2019-03-22     2019-03-29
# 7    1053645660         87  8.042089e+08       2019-04-18     2019-04-26
# 10   1102260248          8  1.088318e+09       2018-07-16     2018-08-01
# ..          ...        ...           ...              ...            ...
# 402     5216219        421  1.382452e+09       2021-06-29     2021-07-07
# 404  1671608614        423  1.290716e+09       2021-06-15     2021-06-23
# 410  1140544457        429  1.023986e+09       2021-07-09     2021-07-19
# 411   742131013        430  1.933385e+09       2021-07-09     2021-07-19
# 412   368912259        431  1.965316e+09       2021-07-09     2021-07-19
#
#      average_daily_car_traffic  average_daily_bike_traffic counter_number  \
# 0                       4949.0                         NaN              6
# 3                       2741.0                         NaN            NaN
# 5                       1046.0                         NaN              2
# 7                       3015.0                         NaN              4
# 10                      5592.0                         NaN            NaN
# ..                         ...                         ...            ...
# 402                     5605.0                         NaN              7
# 404                      809.0                         NaN              1
# 410                      910.0                         NaN              2
# 411                      271.0                         NaN              3
# 412                     3454.0                         NaN              4
#
#     counter_type  speed_limit  ...  longitude   latitude  \
# 0       StatTrak         25.0  ... -79.967772  40.455733
# 3       StatTrak         25.0  ... -79.914335  40.437379
# 5       StatTrak         25.0  ... -80.014234  40.458106
# 7       StatTrak         25.0  ... -79.964592  40.457119
# 10      StatTrak         25.0  ... -79.911925  40.435620
# ..           ...          ...  ...        ...        ...
# 402     StatTrak         25.0  ... -79.926715  40.425958
# 404     StatTrak         25.0  ... -80.010193  40.457801
# 410     StatTrak         25.0  ... -79.940428  40.461034
# 411     StatTrak         25.0  ... -79.953005  40.465173
# 412     StatTrak         25.0  ... -79.955893  40.466231
#
#               neighborhood  council_district  ward        tract  \
# 0              Polish Hill               7.0   6.0  42003060500
# 3      Squirrel Hill South               5.0  14.0  42003140800
# 5        Central Northside               6.0  25.0  42003250300
# 7              Polish Hill               7.0   6.0  42003060500
# 10     Squirrel Hill South               5.0  14.0  42003140800
# ..                     ...               ...   ...          ...
# 402             Greenfield               5.0  15.0  42003151700
# 404      Central Northside               6.0  25.0  42003250300
# 410             Bloomfield               7.0   8.0  42003080600
# 411             Bloomfield               7.0   9.0  42003090300
# 412  Central Lawrenceville               7.0   9.0  42003090200
#
#      public_works_division pli_division  police_zone  fire_zone
# 0                      6.0          6.0          2.0        2-6
# 3                      3.0         14.0          4.0       2-18
# 5                      1.0         25.0          1.0       1-21
# 7                      6.0          6.0          2.0        2-6
# 10                     3.0         14.0          4.0       2-21
# ..                     ...          ...          ...        ...
# 402                    3.0         15.0          4.0       2-15
# 404                    1.0         25.0          1.0       1-21
# 410                    2.0          8.0          5.0       3-23
# 411                    2.0          9.0          5.0        3-6
# 412                    2.0          9.0          2.0        3-3
#
# [286 rows x 25 columns]

# %% [markdown]
# I started by importing the neighborhoods data to be used later, as well as the traffic data. Since I want to measure this metric based on car traffic, I cleaned the data taking out any rows that did not have any car traffic logged.

# %%
traffic_data_and_hood_id = neighborhoods.merge(traffic_data, how='inner', left_on='hood', right_on='neighborhood')
traffic_data_and_hood_id.plot(figsize=(15,10), column='average_daily_car_traffic', legend=True, legend_kwds={'label': 'Average Daily Car Traffic'})

traffic_data_and_hood_id_summed_df = traffic_data_and_hood_id.groupby('hood', as_index=False).mean(numeric_only=True).sort_values('average_daily_car_traffic')
traffic_data_and_hood_id_summed_df.head(10)[['hood', 'average_daily_car_traffic']]
# Out:
#                         hood  average_daily_car_traffic
# 50          South Side Flats                 115.000000
# 31             Lincoln Place                 126.000000
# 32  Lincoln-Lemington-Belmar                 195.000000
# 22                  Fineview                 419.000000
# 1             Allegheny West                 477.000000
# 38             New Homestead                 666.000000
# 41                 Overbrook                 777.000000
# 59               Summer Hill                 937.000000
# 60                Upper Hill                 953.333333
# 13         Central Northside                1189.000000

# %% [markdown]
# The above map illustrates the average car traffic in the neighborhoods of Pittsburgh (that have traffic data). The darker colors on the heatmap represent higher traffic areas, whereas the lighter colored areas represent lower traffic areas. Additionally, we can see the top 10 lowest traffic areas by looking at the head of the sorted dataset. This same information is illustrated on the below bar chart.

# %%
traffic_data_and_hood_id_summed_df.head(15).plot.barh(x='hood', y='average_daily_car_traffic')
# Out:
# <AxesSubplot: ylabel='hood'>

# %% [markdown]
# # Personal Conclusion
# Out of the data that I extracted from this dataset, it is clear that based on the low average daily car traffic that the South Side Flats is the best neighborhood to live in based on the fact that less traffic can dramatically decrease travel time.
